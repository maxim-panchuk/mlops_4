# %%
import numpy as np
import pandas as pd
import os

# %%
data = pd.read_csv(os.path.join('../data', 'BankNote_Authentication.csv'))
data.head()

# %%
X = data[['variance', 'skewness','curtosis','entropy']]
y = data['class']
print(X)
print(y)
# Out:
#       variance  skewness  curtosis  entropy
# 0      3.62160   8.66610   -2.8073 -0.44699
# 1      4.54590   8.16740   -2.4586 -1.46210
# 2      3.86600  -2.63830    1.9242  0.10645
# 3      3.45660   9.52280   -4.0112 -3.59440
# 4      0.32924  -4.45520    4.5718 -0.98880
# ...        ...       ...       ...      ...
# 1367   0.40614   1.34920   -1.4501 -0.55949
# 1368  -1.38870  -4.87730    6.4774  0.34179
# 1369  -3.75030 -13.45860   17.5932 -2.77710
# 1370  -3.56370  -8.38270   12.3930 -1.28230
# 1371  -2.54190  -0.65804    2.6842  1.19520
#
# [1372 rows x 4 columns]
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1367    1
# 1368    1
# 1369    1
# 1370    1
# 1371    1
# Name: class, Length: 1372, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=36)

print(X_train)
print(X_test)
print(y_train)
print(y_test)
# Out:
#       variance  skewness  curtosis   entropy
# 332    3.55940    1.3078   1.29100  1.655600
# 1043  -2.70280    1.6327   0.83598 -0.091393
# 581   -1.96670   11.8052  -0.40472 -7.871900
# 36     2.68810    6.0195  -0.46641 -0.692680
# 1044  -1.49040   -2.2183   1.60540  0.893940
# ...        ...       ...       ...       ...
# 1185  -2.26170   -4.7428   6.34890  0.111620
# 936   -1.27860   -2.4087   4.57350  0.476270
# 926   -0.23356    3.2405  -3.06690 -2.778400
# 610   -0.23610    9.3221   2.13070 -4.379300
# 645    2.92330    6.0464  -0.11168 -0.586650
#
# [1234 rows x 4 columns]
#       variance  skewness  curtosis  entropy
# 16     2.67190   3.06460   0.37158  0.58619
# 1255  -2.50840  -0.22763   1.48800  1.20690
# 1364  -2.83910  -6.63000  10.48490 -0.42113
# 1345   2.22790   4.09510  -4.80370 -2.11120
# 1356  -4.07860   2.92390   0.87026 -0.65389
# ...        ...       ...       ...      ...
# 1067  -0.82601   2.96110  -1.28640 -1.46470
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import export_graphviz
unique_classes = data['class'].unique().tolist()
class_names_list = [str(cls) for cls in unique_classes]

export_graphviz(
    model,
    out_file='tree.dot',
    feature_names=['variance', 'skewness', 'curtosis', 'entropy'],
    class_names=class_names_list
)

# %%
pred = model.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        79
#            1       1.00      0.97      0.98        59
#
#     accuracy                           0.99       138
#    macro avg       0.99      0.98      0.99       138
# weighted avg       0.99      0.99      0.99       138

# %% [markdown]
# ### Inference

# %%
new_data = [[-2.50840,	-0.22763,	1.48800,	1.20690]]
new_data_df = pd.DataFrame(new_data, columns=['variance', 'skewness', 'curtosis', 'entropy'])
predicted_class = model.predict(new_data_df)
print(predicted_class)
# Out:
# [1]
